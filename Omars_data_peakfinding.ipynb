# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Read the CSV file
url = 'https://raw.githubusercontent.com/Sophie-Hilsabeck/SP24-Spectra/main/spe_rowtry2.csv'
data = pd.read_csv(url)

#Assign numerical indices as time
x = np.arange(1, len(data) + 1)


y = data.iloc[:, 0]  # Assuming counts is in the first column

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y, color='blue')
plt.title('Counts vs Time')
plt.xlabel('Time')
plt.ylabel('Count')
plt.grid(True)
plt.show()

#peak finding
peaks, _ = find_peaks(y, height=100)  # Adjust the height as needed

# Plot
plt.figure(figsize=(10, 6))
plt.plot(x, y, color='blue')
plt.plot(x[peaks], y[peaks], 'x', color='red', markersize=10)
plt.title('Peaks on Count vs Time')
plt.xlabel('Time')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# Print peak positions
print("Peak positions (Time):", x[peaks].tolist())
print("Peak Count:", y[peaks].tolist())
# Out:
# Peak positions (Time): [15, 17, 19, 35, 56, 64, 84, 86, 98, 105, 112, 118, 123, 129, 134, 137, 141, 145, 148, 153, 157, 160, 166, 170, 174, 178, 180, 186, 190, 192, 196, 199, 215, 218, 224, 231, 236, 239, 246, 423, 427, 430, 437, 440, 443, 446, 449, 453, 456, 460, 463, 473, 478, 485, 491, 497, 502, 505, 510, 512, 515, 518, 526, 529, 535, 551, 555]
# Peak Count: [171, 222, 205, 9028, 174, 214, 610, 642, 391, 311, 220, 188, 175, 151, 135, 141, 140, 157, 160, 181, 172, 175, 193, 176, 170, 166, 183, 181, 176, 186, 209, 211, 418, 430, 394, 296, 219, 185, 109, 133, 155, 176, 228, 242, 231, 266, 253, 245, 214, 192, 196, 151, 138, 150, 175, 222, 270, 287, 324, 329, 342, 352, 320, 300, 268, 114, 102]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Read the CSV file
url = 'https://raw.githubusercontent.com/Sophie-Hilsabeck/SP24-Spectra/main/spe_rowtry3.csv'
data = pd.read_csv(url)

#Assign numerical indices as time
x = np.arange(1, len(data) + 1)


y = data.iloc[:, 0]  # Assuming counts is in the first column

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y, color='blue')
plt.title('Counts vs Time')
plt.xlabel('Time')
plt.ylabel('Count')
plt.grid(True)
plt.show()

#peak finding
peaks, _ = find_peaks(y, height=100)  # Adjust the height as needed

# Plot
plt.figure(figsize=(10, 6))
plt.plot(x, y, color='blue')
plt.plot(x[peaks], y[peaks], 'x', color='red', markersize=10)
plt.title('Peaks on Count vs Time')
plt.xlabel('Time')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# Print peak positions
print("Peak positions (Time):", x[peaks].tolist())
print("Peak Count:", y[peaks].tolist())
# Out:
# Peak positions (Time): [33, 67, 72, 113, 133, 160, 167, 181, 194, 200, 240, 247, 267, 274, 281, 288, 294, 301, 313, 321, 327, 334, 341, 348, 355, 361, 368, 375, 380, 395, 403, 421, 488, 554, 561, 574, 582, 588, 595, 600, 608, 615, 621, 628, 639, 649, 655, 662, 668, 675, 682, 688, 695, 715, 726, 741, 759, 769, 775, 786, 795, 815, 822, 834, 841, 849, 855, 865, 876, 885, 895, 908, 923, 931, 991, 997, 1003, 1010, 1023, 1077, 1088, 1096, 1103, 1110, 1124, 1137, 1148, 1160, 1166, 1177, 1185, 1197, 1203, 1210, 1217, 1230, 1237, 1243, 1263, 1270, 1284, 1297, 1311, 1319, 1325, 1331, 1344, 1356, 1364, 1377, 1385, 1397, 1407, 1417, 1424, 1436, 1444, 1458, 1463, 1471, 1488, 1499, 1515, 1523]
# Peak Count: [114821, 3724, 3628, 1532, 1174, 1696, 1634, 1439, 1624, 1630, 901, 860, 736, 713, 682, 680, 665, 650, 594, 554, 555, 529, 509, 497, 488, 478, 469, 469, 460, 504, 516, 653, 4988, 888, 846, 842, 806, 790, 786, 770, 758, 751, 701, 701, 666, 657, 666, 650, 638, 661, 635, 638, 623, 550, 518, 469, 428, 397, 400, 386, 363, 321, 320, 304, 290, 273, 282, 259, 258, 261, 245, 251, 262, 259, 917, 944, 965, 918, 799, 248, 224, 217, 200, 194, 188, 182, 166, 169, 162, 167, 163, 146, 149, 162, 147, 147, 149, 146, 144, 139, 140, 137, 133, 133, 135, 132, 128, 129, 128, 130, 127, 122, 123, 115, 113, 114, 107, 104, 112, 109, 105, 102, 100, 104]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# backround
url = 'https://raw.githubusercontent.com/Sophie-Hilsabeck/SP24-Spectra/main/spe_rowtry3.csv'
data = pd.read_csv(url)

#Assign numerical indices as time
x = np.arange(1, len(data) + 1)


y = data.iloc[:, 0]  # Assuming counts is in the first column

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y, color='blue')
plt.title('Counts vs Time')
plt.xlabel('Time')
plt.ylabel('Count')
plt.grid(True)
plt.show()

#peak finding
peaks, _ = find_peaks(y, height=100)  # Adjust the height as needed

# Plot
plt.figure(figsize=(10, 6))
plt.plot(x, y, color='blue')
plt.plot(x[peaks], y[peaks], 'x', color='red', markersize=10)
plt.title('Peaks on Count vs Time')
plt.xlabel('Time')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# Print peak positions
print("Peak positions (Time):", x[peaks].tolist())
print("Peak Count:", y[peaks].tolist())
# Out:
# Peak positions (Time): [33, 67, 72, 113, 133, 160, 167, 181, 194, 200, 240, 247, 267, 274, 281, 288, 294, 301, 313, 321, 327, 334, 341, 348, 355, 361, 368, 375, 380, 395, 403, 421, 488, 554, 561, 574, 582, 588, 595, 600, 608, 615, 621, 628, 639, 649, 655, 662, 668, 675, 682, 688, 695, 715, 726, 741, 759, 769, 775, 786, 795, 815, 822, 834, 841, 849, 855, 865, 876, 885, 895, 908, 923, 931, 991, 997, 1003, 1010, 1023, 1077, 1088, 1096, 1103, 1110, 1124, 1137, 1148, 1160, 1166, 1177, 1185, 1197, 1203, 1210, 1217, 1230, 1237, 1243, 1263, 1270, 1284, 1297, 1311, 1319, 1325, 1331, 1344, 1356, 1364, 1377, 1385, 1397, 1407, 1417, 1424, 1436, 1444, 1458, 1463, 1471, 1488, 1499, 1515, 1523]
# Peak Count: [114821, 3724, 3628, 1532, 1174, 1696, 1634, 1439, 1624, 1630, 901, 860, 736, 713, 682, 680, 665, 650, 594, 554, 555, 529, 509, 497, 488, 478, 469, 469, 460, 504, 516, 653, 4988, 888, 846, 842, 806, 790, 786, 770, 758, 751, 701, 701, 666, 657, 666, 650, 638, 661, 635, 638, 623, 550, 518, 469, 428, 397, 400, 386, 363, 321, 320, 304, 290, 273, 282, 259, 258, 261, 245, 251, 262, 259, 917, 944, 965, 918, 799, 248, 224, 217, 200, 194, 188, 182, 166, 169, 162, 167, 163, 146, 149, 162, 147, 147, 149, 146, 144, 139, 140, 137, 133, 133, 135, 132, 128, 129, 128, 130, 127, 122, 123, 115, 113, 114, 107, 104, 112, 109, 105, 102, 100, 104]
